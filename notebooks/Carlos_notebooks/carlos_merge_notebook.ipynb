# %%
import pandas as pd

# %%
# --- Datasets ---

url_1 = "https://raw.githubusercontent.com/cgveradi/house_martell_project/main/data/raw/df_final_demo.txt" # Demographics Dataset
url_2 = "https://raw.githubusercontent.com/cgveradi/house_martell_project/main/data/raw/df_final_experiment_clients.txt" # Experiment Dataset
url_3_1 = "https://raw.githubusercontent.com/cgveradi/house_martell_project/main/data/raw/df_final_web_data_pt_1.txt" # Web_data part 1 Dataset
url_3_2 = "https://raw.githubusercontent.com/cgveradi/house_martell_project/main/data/raw/df_final_web_data_pt_2.txt" # Web_data part 2 Dataset

# --- Dataframes --- 

df_demo = pd.read_csv(url_1)
df_experiment = pd.read_csv(url_2)
df_web_pt1 = pd.read_csv(url_3_1)
df_web_pt2 = pd.read_csv(url_3_2)
    
    
print(f"df_demo shape: {df_demo.shape}")
print(f"df_experiment shape: {df_experiment.shape}")
print(f"df_web_pt1 shape: {df_web_pt1.shape}")
print(f"df_web_pt2 shape: {df_web_pt2.shape}")
# Out:
# df_demo shape: (70609, 9)
# df_experiment shape: (70609, 2)
# df_web_pt1 shape: (343141, 5)
# df_web_pt2 shape: (412264, 5)

# %%
df_demo.info()

# %%
df_demo

# %%
# --- Rename Columns in df_demo ---
# We observed that column names need adjustment for easy reading and use
df_demo.rename(columns={
    'clnt_age': 'age', 
    'gendr': 'gender', 
    'clnt_tenure_yr': 'tenure_yrs'}, inplace=True)

# %%
df_experiment.info()

# %%
df_experiment

# %%
df_web_pt1.info()

# %%
df_web_pt1

# %%
df_web_pt2.info()

# %%
df_web_pt2

# %%
# --- Combine and Clean Web Data ---
df_web = pd.concat([df_web_pt1, df_web_pt2], ignore_index=True)

# %%
# Convert date_time to datetime object 
df_web['date_time'] = pd.to_datetime(df_web['date_time'])

# %%
df_web

# %%
print(df_web.duplicated().any())
print(df_web.duplicated().sum())

# %%
# Drop duplicate web interaction records
initial_rows = len(df_web)
df_web.drop_duplicates(inplace=True)

# %%
df_web

# %%
print(df_web.duplicated().any())
print(df_web.duplicated().sum())

# %%
# Sort chronologically 
df_web.sort_values(by=['client_id', 'date_time'], inplace=True)

# %%
# --- Merge Datasets ---

df_merged = pd.merge(df_web, df_experiment, on='client_id', how='left')

# %%
df_final = pd.merge(df_merged, df_demo, on='client_id', how='left')

# %%
df_final

# %%
df_final['Variation'].unique()
# Out:
# array(['Test', 'Control', nan], dtype=object)

# %%
print(df_final.duplicated().any())
print(df_final.duplicated().sum())
# Out:
# True
# 10764

# %%
df_clean = df_final.dropna(subset=['Variation']).drop_duplicates().copy()

df_clean.sort_values(by=['client_id', 'date_time'], inplace=True)

# %%
df_clean
# Out:
#         client_id             visitor_id                      visit_id  \
# 72018         555  402506806_56087378777  637149525_38041617439_716659
# 72017         555  402506806_56087378777  637149525_38041617439_716659
# 72016         555  402506806_56087378777  637149525_38041617439_716659
# 72015         555  402506806_56087378777  637149525_38041617439_716659
# 72014         555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 471738    9999729  834634258_21862004160  870243567_56915814033_814203
# 471737    9999729  834634258_21862004160  870243567_56915814033_814203
# 471736    9999729  834634258_21862004160  870243567_56915814033_814203
# 356799    9999832  145538019_54444341400  472154369_16714624241_585315
# 356798    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time Variation  tenure_yrs  \
# 72018         start 2017-04-15 12:57:56      Test         3.0
# 72017        step_1 2017-04-15 12:58:03      Test         3.0
# 72016        step_2 2017-04-15 12:58:35      Test         3.0
# 72015        step_3 2017-04-15 13:00:14      Test         3.0
# 72014       confirm 2017-04-15 13:00:34      Test         3.0
# ...             ...                 ...       ...         ...
# 471738       step_2 2017-05-08 16:08:40      Test        10.0
# 471737       step_3 2017-05-08 16:09:19      Test        10.0
# 471736      confirm 2017-05-08 16:09:40      Test        10.0
# 356799        start 2017-05-16 16:46:03      Test        23.0
# 356798       step_1 2017-05-16 16:46:11      Test        23.0
#
#         clnt_tenure_mnth   age gender  num_accts        bal  calls_6_mnth  \
# 72018               46.0  29.5      U        2.0   25454.66           2.0
# 72017               46.0  29.5      U        2.0   25454.66           2.0
# 72016               46.0  29.5      U        2.0   25454.66           2.0
# 72015               46.0  29.5      U        2.0   25454.66           2.0
# 72014               46.0  29.5      U        2.0   25454.66           2.0
# ...                  ...   ...    ...        ...        ...           ...
# 471738             124.0  31.0      F        3.0  107059.74           6.0
# 471737             124.0  31.0      F        3.0  107059.74           6.0
# 471736             124.0  31.0      F        3.0  107059.74           6.0
# 356799             281.0  49.0      F        2.0  431887.61           1.0
# 356798             281.0  49.0      F        2.0  431887.61           1.0
#
#         logons_6_mnth
# 72018             6.0
# 72017             6.0
# 72016             6.0
# 72015             6.0
# 72014             6.0
# ...               ...
# 471738            9.0
# 471737            9.0
# 471736            9.0
# 356799            4.0
# 356798            4.0
#
# [317235 rows x 14 columns]

# %%
print(df_clean.duplicated().any())
print(df_clean.duplicated().sum())
# Out:
# False
# 0

# %%
df_clean = df_clean.drop_duplicates()

# %%
print(df_clean.duplicated().any())
print(df_clean.duplicated().sum())

# %%
df_clean['gender'] = df_clean['gender'].replace({'M': 'Male','F': 'Female','U': 'Unknown','X': 'Other'})

# %%
df_clean['gender'].nunique()
# Out:
# 4

# %%
df_clean['gender'].value_counts()
# Out:
# gender
# Unknown    107614
# Male       106703
# Female     102810
# Other           8
# Name: count, dtype: int64

# %%
df_clean['gender']
# Out:
# 72018     Unknown
# 72017     Unknown
# 72016     Unknown
# 72015     Unknown
# 72014     Unknown
#            ...
# 471738     Female
# 471737     Female
# 471736     Female
# 356799     Female
# 356798     Female
# Name: gender, Length: 317235, dtype: object

# %%
df_clean
# Out:
#         client_id             visitor_id                      visit_id  \
# 72018         555  402506806_56087378777  637149525_38041617439_716659
# 72017         555  402506806_56087378777  637149525_38041617439_716659
# 72016         555  402506806_56087378777  637149525_38041617439_716659
# 72015         555  402506806_56087378777  637149525_38041617439_716659
# 72014         555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 471738    9999729  834634258_21862004160  870243567_56915814033_814203
# 471737    9999729  834634258_21862004160  870243567_56915814033_814203
# 471736    9999729  834634258_21862004160  870243567_56915814033_814203
# 356799    9999832  145538019_54444341400  472154369_16714624241_585315
# 356798    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time Variation  tenure_yrs  \
# 72018         start 2017-04-15 12:57:56      Test         3.0
# 72017        step_1 2017-04-15 12:58:03      Test         3.0
# 72016        step_2 2017-04-15 12:58:35      Test         3.0
# 72015        step_3 2017-04-15 13:00:14      Test         3.0
# 72014       confirm 2017-04-15 13:00:34      Test         3.0
# ...             ...                 ...       ...         ...
# 471738       step_2 2017-05-08 16:08:40      Test        10.0
# 471737       step_3 2017-05-08 16:09:19      Test        10.0
# 471736      confirm 2017-05-08 16:09:40      Test        10.0
# 356799        start 2017-05-16 16:46:03      Test        23.0
# 356798       step_1 2017-05-16 16:46:11      Test        23.0
#
#         clnt_tenure_mnth   age   gender  num_accts        bal  calls_6_mnth  \
# 72018               46.0  29.5  Unknown        2.0   25454.66           2.0
# 72017               46.0  29.5  Unknown        2.0   25454.66           2.0
# 72016               46.0  29.5  Unknown        2.0   25454.66           2.0
# 72015               46.0  29.5  Unknown        2.0   25454.66           2.0
# 72014               46.0  29.5  Unknown        2.0   25454.66           2.0
# ...                  ...   ...      ...        ...        ...           ...
# 471738             124.0  31.0   Female        3.0  107059.74           6.0
# 471737             124.0  31.0   Female        3.0  107059.74           6.0
# 471736             124.0  31.0   Female        3.0  107059.74           6.0
# 356799             281.0  49.0   Female        2.0  431887.61           1.0
# 356798             281.0  49.0   Female        2.0  431887.61           1.0
#
#         logons_6_mnth
# 72018             6.0
# 72017             6.0
# 72016             6.0
# 72015             6.0
# 72014             6.0
# ...               ...
# 471738            9.0
# 471737            9.0
# 471736            9.0
# 356799            4.0
# 356798            4.0
#
# [317235 rows x 14 columns]

# %%
# Exporting the cleaned dataset
df_clean.to_csv('df_clean.csv', index=False, encoding='utf-8')
